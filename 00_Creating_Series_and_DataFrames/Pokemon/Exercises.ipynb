# %% [markdown]
# # Pokemon

# %% [markdown]
# ### Introduction:
#
# This time you will create the data.
#
#
#
# ### Step 1. Import the necessary libraries

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### Step 2. Create a data dictionary that looks like the DataFrame below

# %%
data = {"evolution" : pd.Series(["Ivysaur", "Charmeleon", "Wartortle", "Metapod"])
        , "hp" : pd.Series([45, 39, 44, 45 ])
        , "name" : pd.Series(["Bulbasaur", "Charmander", "Squirtle", "Caterpie"])
        , "pokedex" : pd.Series(["yes", "no", "yes", "no"])
        , "type" : pd.Series(["grass", "fire", "water", "bug"])
        }

# %% [markdown]
# ### Step 3. Assign it to a variable called pokemon

# %%
pokemon = pd.DataFrame(data)
pokemon
# Out:
#     evolution  hp        name pokedex   type
# 0     Ivysaur  45   Bulbasaur     yes  grass
# 1  Charmeleon  39  Charmander      no   fire
# 2   Wartortle  44    Squirtle     yes  water
# 3     Metapod  45    Caterpie      no    bug

# %%
# Out:
#     evolution  hp        name pokedex   type
# 0     Ivysaur  45   Bulbasaur     yes  grass
# 1  Charmeleon  39  Charmander      no   fire
# 2   Wartortle  44    Squirtle     yes  water
# 3     Metapod  45    Caterpie      no    bug

# %% [markdown]
# ### Step 4. Ops...it seems the DataFrame columns are in alphabetical order. Place  the order of the columns as name, type, hp, evolution, pokedex

# %%
df = pokemon[["name", "type", "hp", "evolution", "pokedex"]]

# %%
df
# Out:
#          name   type  hp   evolution pokedex
# 0   Bulbasaur  grass  45     Ivysaur     yes
# 1  Charmander   fire  39  Charmeleon      no
# 2    Squirtle  water  44   Wartortle     yes
# 3    Caterpie    bug  45     Metapod      no

# %% [markdown]
# ### Step 5. Add another column called place, and insert what you have in mind.

# %%
df["place"] = ["HaNoi", "BaiChay", "QuangNinh", "Siu"]
# Out:
# <ipython-input-12-b5c352a52c9f>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["place"] = ["HaNoi", "BaiChay", "QuangNinh", "Siu"]

# %%
df
# Out:
#          name   type  hp   evolution pokedex      place
# 0   Bulbasaur  grass  45     Ivysaur     yes      HaNoi
# 1  Charmander   fire  39  Charmeleon      no    BaiChay
# 2    Squirtle  water  44   Wartortle     yes  QuangNinh
# 3    Caterpie    bug  45     Metapod      no        Siu

# %% [markdown]
# ### Step 6. Present the type of each column

# %%
df.dtypes
# Out:
# name         object
# type         object
# hp            int64
# evolution    object
# pokedex      object
# place        object
# dtype: object

# %% [markdown]
# ### BONUS: Create your own question and answer it.
